# %%
from ultralytics import YOLO

# Load a model checkpoint (choose one)
# yolov9t.pt  - tiny
# yolov9s.pt  - small
# yolov9m.pt  - medium
# yolov9c.pt  - large
# yolov9e.pt  - extra large, highest accuracy
model = YOLO("yolov9e.pt")

model.train(
    data="X:/Epics/Acidental/data.yaml",  # path to your YAML
    epochs=25,                           # recommend higher for CCTV
    imgsz=250,                            # CCTV usually 640–1280
    batch=6,
    workers=8,
    device=0,                             # your GPU
)
# Out:
# New https://pypi.org/project/ultralytics/8.4.30 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.198  Python-3.10.0 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# ...

# %%
from ultralytics import YOLO

# Load a model checkpoint (choose one)
# yolov9t.pt  - tiny
# yolov9s.pt  - small
# yolov9m.pt  - medium
# yolov9c.pt  - large
# yolov9e.pt  - extra large, highest accuracy
model = YOLO("yolov9e.pt")

model.train(
    data="X:/Epics/Acidental/data.yaml",  # path to your YAML
    epochs=25,                           # recommend higher for CCTV
    imgsz=250,                            # CCTV usually 640–1280
    batch=6,
    workers=8,
    device=0,                             # your GPU
)
# Out:
# New https://pypi.org/project/ultralytics/8.4.30 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.198  Python-3.10.0 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# ...

# %%
model2 = YOLO("X:/Epics/Acidental/runs/detect/train1/weights/best.pt")

# %%
test_metrics = model2.val(
    data="X:/Epics/Acidental/data.yaml",
    split="test",
    save_json=True,      # COCO-style results
    save_hybrid=True
)

print(test_metrics.box.map50)
# Out:
# WARNING 'save_hybrid' is deprecated and will be removed in the future.
# Ultralytics 8.3.198  Python-3.10.0 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# val: Fast image access  (ping: 0.20.1 ms, read: 20.09.0 MB/s, size: 105.6 KB)
# val: Scanning X:\Epics\Acidental\test\labels... 215 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 215/215 1.3Kit/s 0.2s<0.2s
# val: New cache created: X:\Epics\Acidental\test\labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 6.2it/s 2.3s0.1s
#                    all        215        381      0.869       0.87      0.927      0.717
#               accident        200        217       0.87      0.897      0.941      0.711
#           non-accident         77        164      0.868      0.844      0.914      0.724
# Speed: 0.1ms preprocess, 7.2ms inference, 0.0ms loss, 0.7ms postprocess per image
# ...
